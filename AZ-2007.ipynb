# %%
https://learn.microsoft.com/ja-jp/training/paths/accelerate-app-development-using-github-copilot/

# %%
演習 - GitHub Copilot の設定とユーザー インターフェイスの機能を調べる
https://microsoftlearning.github.io/mslearn-github-copilot-dev/Instructions/Labs/LAB_AK_01_examine_settings_interface.html

# %%
演習 - GitHub Copilot を使用してコードを分析してドキュメント化する
https://microsoftlearning.github.io/mslearn-github-copilot-dev/Instructions/Labs/LAB_AK_02_analyze_document_code.html

ダウンロードリソース
https://github.com/MicrosoftLearning/mslearn-github-copilot-dev/raw/refs/heads/main/DownloadableCodeProjects/Downloads/AZ2007LabAppM2.zip

補足
dotnet new sln -n AccelerateDevGHCopilot

# %%
演習 - GitHub Copilotを使用して新しいコード機能を開発する
https://microsoftlearning.github.io/mslearn-github-copilot-dev/Instructions/Labs/LAB_AK_03_develop_code_features.html

ダウンロードリソース
https://github.com/MicrosoftLearning/mslearn-github-copilot-dev/raw/refs/heads/main/DownloadableCodeProjects/Downloads/AZ2007LabAppM3.zip

補足
dotnet new sln -n AccelerateDevGHCopilot
dotnet sln AccelerateDevGHCopilot.slnx add src/Library.ApplicationCore/Library.ApplicationCore.csproj
dotnet sln AccelerateDevGHCopilot.slnx add src/Library.Console/Library.Console.csproj
dotnet sln AccelerateDevGHCopilot.slnx add src/Library.Infrastructure/Library.Infrastructure.csproj
dotnet sln AccelerateDevGHCopilot.slnx add tests/UnitTests/UnitTests.csproj

# %%
演習 - GitHub Copilot を使用して単体テストを開発する
https://microsoftlearning.github.io/mslearn-github-copilot-dev/Instructions/Labs/LAB_AK_04_develop_unit_tests_xunit.html

ダウンロードリソース
https://github.com/MicrosoftLearning/mslearn-github-copilot-dev/raw/refs/heads/main/DownloadableCodeProjects/Downloads/AZ2007LabAppM4.zip

# %%
演習 - GitHub Copilotを使用して既存のコードをリファクタリングする
https://microsoftlearning.github.io/mslearn-github-copilot-dev/Instructions/Labs/LAB_AK_05_refactor_improve_existing_code.html

ダウンロードリソース
https://github.com/MicrosoftLearning/mslearn-github-copilot-dev/raw/refs/heads/main/DownloadableCodeProjects/Downloads/AZ2007LabAppM5.zip

# %%
演習 - GitHub Copilot Agent を使用して Vibe コーディングを開始する
https://microsoftlearning.github.io/mslearn-github-copilot-dev/Instructions/Labs/LAB_AK_06_vibe_coding_prototype_ecommerce_app.html
